# %% [markdown]
# <a href="https://colab.research.google.com/github/saneseydou/SQL/blob/master/panda_ydata_profiling_checkpoint_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ydata-profiling         #install

# %%
import pandas as pd                           #importation
from ydata_profiling import ProfileReport     #importation

#chargement de données
diabetes=pd.read_csv("diabetes.csv")

#display des premières lignes

diabetes.head()

# %%
#Affichez la structure du jeu de données, y compris les noms des colonnes, les types de données et l'utilisation de la mémoire.

diabetes.info()

# %%
#Identifiez le nombre de valeurs manquantes ou de zéros dans l'ensemble de données.

diabetes.isnull().sum()

# %%
#Utilisez la fonction describe() pour analyser:

diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # ANALYSE DE DONNEES //
#
# EValeurs Manquantes //
#
# En exploitant pandas profiling: pour la  variable (Glucose) on a Missing values =0  //
# En exploitant pandas profiling: pour la  variable (Insulin) on a Missing values =0  //
# En exploitant pandas profiling: pour la  variable (BMI) on a Missing values =0 //
#
#
# Le graphique Missing values montre que les parametre ont la même proportionalité sans valeurs manquantes

# %% [markdown]
# Exploration des données avec ydata-profiling
# Générer un rapport de profilage
#
# bultin=ProfileReport(diabetes, title="releve_medical")
# # Display the report
# bultin.to_notebook_iframe()

# %% [markdown]
# ANALYSE SUR LE PLAN UNIVARIE DE LA VARIABLE

# %%
Age_counts=diabetes["Age"].value_counts()
Age_counts

# %% [markdown]
# Nous avons une fréquence d'Age qui varie entre 35 et 44 avec **une moyonne de la série égale à 33.24 Ans**

# %%
Glycemie_counts=diabetes["Glucose"].value_counts()
Glycemie_counts

# %% [markdown]
# les taux de Glucose les plus fréquent varient entre 99 et 125. Avec **une moyenne de la serie égale à 129.89**

# %% [markdown]
# **ANALYSE SUR LE PLAN BIVARIE**
#
# <!-- diabetes.loc[diabetes["Glucose"],["Age"]] -->

# %% [markdown]
# D'abord il existe un interaction forte entre le taux de Glucose et l'Age pour les personnes d'une age supérieur à 70 ans.//
#
# #La faible interaction chez les personnes jeunes correspondrait à un faible risque.

# %% [markdown]
# Il existe une interaction forte entre population jeune sur des intervalle de prédiction très faible. Cependant, sur les intervalle de prédiction à risque l'interaction est faible.
#
# #Le risque de présence de diabetes chez notre population serait faible.

# %% [markdown]
# Nous avons une interaction forte avec des taux de glucose fort avec des prédictions fortes
#
# #La forte prédiction est lié au taux de glucose

# %% [markdown]
# Pour les grossesses l'interaction n'est forte que sur des duréé de grossesses supérieur à la normale

# %% [markdown]
# Plus l'indice de masse corporelle est fort plus le taux de glucose augmente.

# %% [markdown]
# l'indice de masse corporelle est en forte interaction chez une couche de la population de 20 à 40 ans

# %% [markdown]
# Y a t-il un rapporte entre la prédiction du diabet les autres paramètres ?

# %% [markdown]
# #RESUME DE L'ANALYSE

# %% [markdown]
# Bien que la moyenne de notre population soit contenu dans l'intervalle de l'indice de masse corporelle, l'analyse des données indique la relation de causialité entre prédiction de diabete et le taux de glucose.
#
# Comptenu de l'analyse bivariée AGE et Glucose, nous estimons qu'un lien entre le diabete et l'Age.

# %% [markdown]
# il est nécessaire d'apporter des correction sur les valeurs de grossesses supérieur à la moyenne.

# %%
# Out:
#      Age
# 148   65
# 85    27
# 183   27
# 89    24
# 137   22
# ..   ...
# 101   22
# 122   23
# 121   24
# 126   30
# 93    60
#
# [768 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
