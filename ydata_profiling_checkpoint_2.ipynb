# %% [markdown]
# <a href="https://colab.research.google.com/github/saneseydou/SQL/blob/master/ydata_profiling_checkpoint_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ydata-profiling checkpoint 2
#
# check point sur les données de 'La compagnie aérienne tunisienne : Tunisair' dataset.

# %% [markdown]
# Partie 1 : Exploration de données avec Pandas
#
# 1.	Chargez l'ensemble de données fourni dans un cadre de données pandas
#
# 2.	Utilisez pandas pour explorer l'ensemble de données. Par exemple, vous pouvez commencer par utiliser les méthodes head() et info() pour obtenir une vue d'ensemble des données.

# %%
# !pip install -U ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport


Tunisair=pd.read_csv("Tunisair_flights_dataset.csv")

Tunisair.head()
# Out:
#   Filght_date Flight_ID Departure point Arrival point  \
# 0  2016-01-03  TU 0712              CMN           TUN
# 1  2016-01-13  TU 0757              MXP           TUN
# 2  2016-01-16  TU 0214              TUN           IST
# 3  2016-01-17  TU 0480              DJE           NTE
# 4  2016-01-17  TU 0338              TUN           ALG
#
#   Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0      2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1      2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# 2      2016-01-16 04:10:00    2016-01-16 06.45.00    ATA     TU 32AIMN
# 3      2016-01-17 14:10:00    2016-01-17 17.00.00    ATA     TU 736IOK
# 4      2016-01-17 14:30:00    2016-01-17 15.50.00    ATA     TU 320IMU
#
#    Arrival delay
# 0          260.0
# 1           20.0
# 2            0.0
# 3            0.0
# 4           22.0

# %%
Tunisair.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107833 entries, 0 to 107832
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Filght_date               107833 non-null  object
#  1   Flight_ID                 107833 non-null  object
#  2   Departure point           107833 non-null  object
#  3   Arrival point             107833 non-null  object
#  4   Scheduled_departure_time  107833 non-null  object
#  5   Scheduled_arrival_time    107833 non-null  object
#  6   STATUS                    107833 non-null  object
#  7   Aircraft_code             107833 non-null  object
#  8   Arrival delay             107833 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 7.4+ MB

# %% [markdown]
# 3.	Recherchez les valeurs manquantes dans l'ensemble de données. Vous pouvez utiliser la méthode isnull() pour identifier les valeurs manquantes.

# %%
Tunisair.isnull().sum()
# Out:
# Filght_date                 0
# Flight_ID                   0
# Departure point             0
# Arrival point               0
# Scheduled_departure_time    0
# Scheduled_arrival_time      0
# STATUS                      0
# Aircraft_code               0
# Arrival delay               0
# dtype: int64

# %% [markdown]
# nous n'avons pas de valeur nulle dans notre **Tunisair**

# %% [markdown]
# 4.	Utilisez pandas pour calculer des statistiques sommaires pour l'ensemble de données. Par exemple, vous pouvez utiliser la méthode describe() pour obtenir des statistiques sommaires pour les colonnes numériques de l'ensemble de données.

# %%
Tunisair.describe()
# Out:
#        Arrival delay
# count  107833.000000
# mean       48.733013
# std       117.135562
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        43.000000
# max      3451.000000

# %% [markdown]
# **Partie 2 : Exploration des données avec ydata-Profiling**
#
# 1.	Utilisez ydata-profiling pour générer un rapport sur l'ensemble de données fourni.

# %%
bultin=ProfileReport(Tunisair, title="gestion aéroportuaire Tunisair")
bultin.to_file("gestion aéroportuaire Tunisair.html")      #affichage sur html

# %% [markdown]
# 2.	Recherchez les valeurs manquantes dans l'ensemble de données. Vous pouvez utiliser le rapport généré par ydata-profiling pour identifier les valeurs manquantes.
#
# #Notre base de données ne présente pas de valeurs manquantes

# %% [markdown]
# 3.	Recherche de corrélations entre les différentes colonnes de l'ensemble de données. Vous pouvez utiliser le rapport généré par ydata-profiling pour identifier les corrélations entre différentes colonnes.
#
#
# #Suite à l'analyse effectuer sur le rapport ydata profiling, il semble révéler une corrélation positive entrre le STATUS et ARRIVAL DELAY

# %% [markdown]
# 4.	Identifier toute valeur aberrante ou inhabituelle dans l'ensemble de données. Vous pouvez utiliser le rapport généré par ydata-profiling pour identifier les valeurs aberrantes ou inhabituelles.
#
# - Nous avons deux probèmes majeurs dans nos données.
# #un déséquilibre élevé sur le STATUS
# # des valeurs abérantes sur le delai d'arrivé

# %% [markdown]
# # **RESUME**

# %% [markdown]
# L'exporation de nos données avec pandas nous a permis de résumer notre masse de donnée offrant une vu d'ensemble. ce qui nous renseigne l'abscence de valeurs manquantes, la présences de valeurs abérantes et anormales mais sur de la corrélation qu'il y a dans nos colonnes STATUS ET DELAI D'ARRIVE.
